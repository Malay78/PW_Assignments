# %%
Q1. Create a Pandas Series that contains the following data: 4, 8, 15, 16, 23, and 42. Then, print the series.

# %%
#Code1-
import pandas as pd
a=[10,12,15,18,21,25]
pd.Series(a)
# Out:
# 0    10
# 1    12
# 2    15
# 3    18
# 4    21
# 5    25
# dtype: int64

# %%
Q2. Create a variable of list type containing 10 elements in it, and apply pandas.Series function on the 
variable print it.

# %%
#Code2-
flag= ['Pink', 'Red', 'Blue', 'Black', 'White', "Brown",'Purple','Yellow','Green','Orange']
pd.Series(flag)
# Out:
# 0      Pink
# 1       Red
# 2      Blue
# 3     Black
# 4     White
# 5     Brown
# 6    Purple
# 7    Yellow
# 8     Green
# 9    Orange
# dtype: object

# %%
Q3. Create a Pandas DataFrame that contains the following data:
Then, print the DataFrame.

# %%
#Code3-
value = [['Alice', 25, 'Female'], ['Bob', 30, 'Male'], ['Claire',27,'Male']]
df = pd.DataFrame(value, columns=['Name', 'Age', 'Gender'])
df.style.hide_index()
#print(df.to_string(index = False))
# Out:
# C:\Users\Malay Gupta\AppData\Local\Temp\ipykernel_15144\4767479.py:4: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   df.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_b4baf">
#   <thead>
#     <tr>
#       <th id="T_b4baf_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_b4baf_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_b4baf_level0_col2" class="col_heading level0 col2" >Gender</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b4baf_row0_col0" class="data row0 col0" >Alice</td>
#       <td id="T_b4baf_row0_col1" class="data row0 col1" >25</td>
#       <td id="T_b4baf_row0_col2" class="data row0 col2" >Female</td>
#     </tr>
#     <tr>
#       <td id="T_b4baf_row1_col0" class="data row1 col0" >Bob</td>
#       <td id="T_b4baf_row1_col1" class="data row1 col1" >30</td>
#       <td id="T_b4baf_row1_col2" class="data row1 col2" >Male</td>
#     </tr>
# ...

# %%
Q4. What is ‘DataFrame’ in pandas and how is it different from pandas.series? Explain with an example.
#Ans4.
A pandas DataFrame is a 2 Dimensional data structure, like a 2 dimensional array, or a table with rows and columns. Dataframe
are the most common used data structures used in modern data analytics because they are a flexible and intuitive way of 
storing and working with data.

pandas.series is a one-dimensitonal labeled array capable of holding data of any type(integer, string, float, python,
objects, etc.)

# %%
#Example for Series
print("Example for Series")
data= [100,95,97,39,85,79]
s=pd.Series(data)
print(s)
print("\nExample for Dataframe")
data= [81,85,74,90,75,76]
df= pd.DataFrame(data, columns=['Column1'])
print(df)
# Out:
# Example for Series
# 0    100
# 1     95
# 2     97
# 3     39
# 4     85
# 5     79
# dtype: int64
#
# Example for Dataframe
#    \tColumn1
# 0         81
# 1         85
# 2         74
# 3         90
# 4         75
# 5         76

# %%
Q5. What are some common functions you can use to manipulate data in a Pandas DataFrame? Can 
you give an example of when you might use one of these functions?

# %%
#Ans5.
Functions used in Pandas to manipulate data:-
* abs()- Return a DataFrame with the absolute value of each value
* add()- Adds the values of a DataFrame with the specified value(s)
* align()- Aligns two DataFrames with a specified join method
* all()- Return True if all values in the DataFrame are True, otherwise False
* append()- Append new columns
* assign()- Assign new clolumns
* bool()- Returns the Boolean value of the DataFrame
* count()- Returns the number of not empty cells for each columns/row.
* copy()- Returns a copy of the DataFrame
* cumsum()- Calculate the cummulative sum over the DataFrame.
* dot()- Multiplies the values of a DataFrame with values from another array-like object, and add the result
* drop()- Drops the specified rows/columns from the DataFrame
* head()- Returns the header row and the first 10 rows, or the specified number of rows
* last()- Returns the last row of a specified date selection

# %%
df= pd.read_csv("services.csv")
df.drop('email', axis='columns')
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
Q6. Which of the following is mutable in nature Series, DataFrame, Panel?
#Ans6.
The panel is a three-dimensional data-structure with heterogeneous data. It is very hard to represent the Panel in a 
graphical representation.
In Panel, data and size are mutable.

# %%
Q7. Create a DataFrame using multiple Series. Explain with an example.

# %%
name=['Tom','David','Stuart','James','Aiden']
city=['Auckland', 'Canberra','Delhi', 'Wellington', 'CapeTown']
df4= pd.Series(name)
df5= pd.Series(city)
df6 = pd.concat([df4, df5], axis=1)
print(df6)
# Out:
#         0           1
# 0     Tom    Auckland
# 1   David    Canberra
# 2  Stuart       Delhi
# 3   James  Wellington
# 4   Aiden    CapeTown
