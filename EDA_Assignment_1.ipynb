# %% [markdown]
# # EDA Assignment-1

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Q1. What are the key features of the wine quality data set? Discuss the importance of each feature in
# predicting the quality of wine

# %%
#Ans1
df = pd.read_csv("winequality-red.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# Fixed acidity - It describes the measure of acidity in the Wine.
#
# Volatile acidity- It shows that the acidity is volatile in nature or not.
#
# Citric acid- It shows the sourness of the wine.
#
# Alcohol: The percentage of alcohol in the wine
#
# Density: Sweeter wines have a higher density
#
# Fixed acidity: Non-volatile acids that do not evaporate easily
#
# pH: The level of acidity, on a scale from 0 (very acidic) to 14 (very basic)
#
# Sulphates: A wine additive that contributes to SO2 levels and acts as an antioxidant and antimicrobial
#
# Quality: The output variable, based on sensory data and scored between 0 and 10
#
# residual sugar- It describes the sugar added in the wine.
#
# chlorides- Chlorides are added to make the wine more hard.

# %% [markdown]
# Q2. How did you handle missing data in the wine quality data set during the feature engineering process?
# Discuss the advantages and disadvantages of different imputation techniques.

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Handling Missing Data-
# We apply Feature Engineering Techniques like One Hot Encoding, Label Encoding to fill that blank space in the missing
# value by calculating its mean, median or mode.
#
# Advantages-
# - Model clarity: Models are easier to understand and maintain
# - Model accuracy: Models are more accurate and have faster response times
# - Model robustness: Models are more robust
#
# Disadvantages-
# - Data quality: Data quality issues, like missing values, outliers, and errors, can impact model performance
# - Overfitting: Feature engineering can increase the risk of overfitting if the feature selection or transformation is
#     too complex
# - Domain knowledge: Feature engineering is subjective and requires domain knowledge and creativity to identify relevant
#     variables

# %% [markdown]
# Q3. What are the key factors that affect students' performance in exams? How would you go about
# analyzing these factors using statistical techniques?

# %%
df1 = pd.read_csv('stud.csv')
df1.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# Key factors that affect students' performance-
# - parental_level_of_education - The major effect on student performance is the qualification of their parents.
#
# - lunch- There are two types of lunch present in the dataset(i.e. standard and free/reduced) which also specifies the
#         performance of the student.
#
# - test_preparation_course- Some students didn't complete their Preparation course which decrease their performance.

# %% [markdown]
# Q4. Describe the process of feature engineering in the context of the student performance data set. How
# did you select and transform the variables for your model?

# %% [markdown]
# #Ans4
# 1. Feature Transformation- As in the student performance dataset all the
#     elements are numeric. So no need for transformation.
# 2. Categorical Variable Encoding- Convert categorical attributes to numerical
#     representations using appropriate encoding methods. Like we can covert the
#     gender Male and Female to binary digits(0 and 1).
# 3. Outlier Handling - Identify and handle outliers that could impact model
#     performance particularly in the exam scores. Use techniques like
#     Z-score or IQE-based methods.
# 4. Data Cleaning- Handling with the missing values in the dataset.

# %% [markdown]
# Q5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distribution
# of each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to
# these features to improve normality?

# %%
#Ans5
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
skewness = df.skew()
kurtosis = df.kurtosis()
print("---------------------Skewness--------------------")
print(skewness)
print("---------------------Kurtosis--------------------")
print(kurtosis)
# Out:
# ---------------------Skewness--------------------
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64
# ---------------------Kurtosis--------------------
# fixed acidity            1.132143
# volatile acidity         1.225542
# citric acid             -0.788998
# residual sugar          28.617595
# chlorides               41.715787
# free sulfur dioxide      2.023562
# total sulfur dioxide     3.809824
# density                  0.934079
# pH                       0.806943
# sulphates               11.720251
# alcohol                  0.200029
# quality                  0.296708
# dtype: float64

# %%
plt.figure(figsize = (18,13))
for i, col in enumerate(list(df.columns.values)):
    plt.subplot(4,3, i+1)
    sns.histplot(df[col], color = 'r', kde = True)
    plt.grid()
    plt.tight_layout()

# %% [markdown]
# Q6. Using the wine quality data set, perform principal component analysis (PCA) to reduce the number of
# features. What is the minimum number of principal components required to explain 90% of the variance in
# the data?

# %%
#Ans6
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
data = pd.read_csv('winequality-red.csv')
X = data.drop('quality', axis=1)
y = data['quality']
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

explained_variance_ratio = pca.explained_variance_ratio_
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio.cumsum(), marker='o', linestyle='--')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Explained Variance by Principal Components')
plt.grid(True)
plt.show()
cumulative_variance = explained_variance_ratio.cumsum()
min_components = len(cumulative_variance[cumulative_variance < 0.90]) + 1
