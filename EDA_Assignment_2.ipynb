# %% [markdown]
# # Assignment- Exploratory Data Analysis-2

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
#Ans1.
df = pd.read_excel("flight_price.xlsx")
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.shape
# Out:
# (10683, 11)

# %% [markdown]
# Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the distribution.

# %%
#Ans2. 
plt.figure(figsize = (10,6))
sns.histplot(data = df, x= 'Price', bins = 25, kde = True)
plt.xlabel("Ticket Price")
plt.ylabel("Ticket Counts")
# Out:
# Text(0, 0.5, 'Ticket Counts')

# %% [markdown]
# Q3. What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
#Ans3.
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
#Minimum Price
df.Price.min()
# Out:
# 1759

# %%
#Maximum Price
df.Price.max()
# Out:
# 79512

# %% [markdown]
# Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different airlines.

# %%
#Ans4.
plt.figure(figsize =  (10,6))
sns.boxplot(data = df, x = 'Airline', y = 'Price')
plt.xticks(rotation = 45, ha = 'right')
plt.xlabel('Airline')
plt.ylabel('Ticket Price')
# Out:
# Text(0, 0.5, 'Ticket Price')

# %% [markdown]
# Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how they may impact your analysis.

# %%
#Ans5.
plt.figure(figsize =  (10,6))
sns.boxplot(data = df, x = 'Airline', y = 'Price')
plt.xticks(rotation = 45, ha = 'right')
plt.xlabel('Airline')
plt.ylabel('Ticket Price')
# Out:
# Text(0, 0.5, 'Ticket Price')

# %% [markdown]
# There are number of outliers present in the boxplots, those dots are showing
#  that are said to be ouliers. It affects the statistical analysis like mean,
#  median, mode.

# %% [markdown]
# Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset to identify the peak travel season. What features would you analyze to identify the peak season, and how would you present your findings to your boss?

# %% [markdown]
# Analysis-
# - Categorize months into seasons(like winter, summer, autumn, raniny) and
# analyze average prices
# - Analyze whether flight prices vary based on the day of the week.
# - Identify those months with higher average prices.
# - Analyze Historical Data (About Peak Seasons etc.) and compare them with
# the current scenario
# -Analyze the demands and supply
#
# Outcomes-
# - Intro- Purpose of the analysis.
# - Summarize the main finding for each feature analaysed.
# - Peak Travel Season Identification
# - Suggest focusing on marketing efforts, promotions, and discounts during the
# identified peak travel season to attract more customers.
# - Discuss the potentia impact of the peak travel season on the company's revenue.
# - Conclusion

# %% [markdown]
# Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight Price dataset to identify any trends in flight prices. What features would you analyze to identify these trends, and what visualizations would you use to present your findings to your team?

# %% [markdown]
# #Ans7.
# Analysis-
# - Categorize months into seasons(like winter, summer, autumn, raniny) and analyze average prices
# - Analyze whether flight prices vary based on the day of the week.
# - Identify those months with higher average prices.
# - Analyze Historical Data (About Peak Seasons etc.) and compare them with the current scenario -Analyze the demands and supply
#
# Visualizations-
# - Boxplots(To show categorical variables)
# - Scatter Plots(To show correalation among the different features)
# - Histograms
# - Line Plots

# %% [markdown]
# Q8. You are a data scientist working for an airline company, and you have been asked to analyze the Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to identify these factors, and how would you present your findings to the management team?

# %% [markdown]
# #Ans8.
# Features to Analyze-
# - Categorize months into seasons(like winter, summer, autumn, raniny) and analyze average prices
# - Analyze whether flight prices vary based on the day of the week.
# - Identify those months with higher average prices.
# - Analyze Historical Data (About Peak Seasons etc.) and compare them with the current scenario -Analyze the demands and supply
#
# Outcomes-
# - Intro(Explains the objective)
# - Main Factors that affects the flight prices based on the anaysis
# - Usage of statistical and visualizations insights to support your findings.
# - Provide acitonable recommendations to the management team.
# - Data-driven Insights

# %% [markdown]
# # Google Playstore

# %% [markdown]
# Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does
# the dataset have?

# %%
#Ans9.
df = pd.read_csv("googleplaystore.csv")
df.shape
# Out:
# (10841, 13)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different
# app categories.

# %%
#Ans10.
sns.boxplot(x =  df.Rating  , y =df.Category )
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='Category'>

# %% [markdown]
# Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may
# impact your analysis.

# %%
#Ans11.
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
Yes there are missing values in Columns- Rating(1474), Type(1), Content Rating(1), Current Ver(8), Android Ver(3)

#Impact
If values are missing systematically, analysis may be biased.

# %% [markdown]
# Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize
# the relationship.

# %%
#Ans12.
plt.figure(figsize = (11,7))
sns.scatterplot(data = df, x = 'Size', y = 'Rating')
plt.xlabel("Size of the app")
plt.ylabel("Rating")
# Out:
# Text(0, 0.5, 'Rating')

# %% [markdown]
# Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df['Price'] = df['Price'].str.replace('$', '').str.replace('Everyone', str(np.nan))
# Out:
# C:\Users\Malay Gupta\AppData\Local\Temp\ipykernel_8980\1994204052.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Price'] = df['Price'].str.replace('$', '').str.replace('Everyone', str(np.nan))

# %%
df['Price'] = df['Price'].astype(float)

# %%
plt.figure(figsize = (10,6))
sns.barplot(data = df, x = 'Category', y= 'Price', ci = False)
plt.xticks(rotation = 45, ha = 'right')
plt.xlabel("Category Type")
plt.ylabel("Prices")
plt.show()
# Out:
# C:\Users\Malay Gupta\AppData\Local\Temp\ipykernel_8980\1033050090.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(data = df, x = 'Category', y= 'Price', ci = False)

# %% [markdown]
# Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps
# with the highest number of installs.

# %%
#Ans14.
df = df.drop_duplicates(subset = ['App'], keep = 'first')
df['Installs'] = df['Installs'].str.replace('+', '').str.replace('Free', '')

# %%
df = df.drop(df.index[10472], axis = 0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df = df.drop(df.index[10472], axis = 0)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:5320, in Index.__getitem__(self, key)
#    5317 if is_integer(key) or is_float(key):
#    5318     # GH#44051 exclude bool, which would return a 2d ndarray
#    5319     key = com.cast_scalar_indexer(key, warn_float=True)
# -> 5320     return getitem(key)
#    5322 if isinstance(key, slice):
#    5323     # This case is separated from the conditional above to avoid
#    5324     # pessimization com.is_bool_indexer and ndim checks.
#    5325     result = getitem(key)
#
# IndexError: index 10472 is out of bounds for axis 0 with size 9660

# %%
#df['Installs'] = df['Installs'].astype(int)
df.groupby([ 'App'])['Rating'].sum().sort_values( ascending = False).to_frame().head(10)
# Out:
#                                                 Rating
# App
# Life Made WI-Fi Touchscreen Photo Frame           19.0
# Unity CF                                           5.0
# Prosperity                                         5.0
# EP Church Annapolis                                5.0
# Pyaar Ek Dhoka                                     5.0
# Bacterial vaginosis Treatment - Sexual disease     5.0
# EP Radio                                           5.0
# ER Assist                                          5.0
# ES Billing System (Offline App)                    5.0
# Propel BI APP                                      5.0

# %% [markdown]
# Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the
# Google Playstore dataset to identify the most popular app categories. How would you approach this
# task, and what features would you analyze to make recommendations to the company?

# %%
#Ans15.
df.drop_duplicates(inplace =True)
df.reset_index(drop =  True)
# Out:
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                   Coloring book moana       ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                 ...                  ...
# 9655                                   Sya9a Maroc - FR               FAMILY
# 9656                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 9657                             Parkinson Exercices FR              MEDICAL
# 9658                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 9659      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
category = pd.DataFrame(df['Category'].value_counts())
category.rename(columns = {'Category': 'Count'}, inplace = True)
category[:10]
# Out:
#                  Count
# FAMILY            1832
# GAME               959
# TOOLS              827
# BUSINESS           420
# MEDICAL            395
# PERSONALIZATION    376
# PRODUCTIVITY       374
# LIFESTYLE          369
# FINANCE            345
# SPORTS             325

# %% [markdown]
# Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify the
# most successful app developers. What features would you analyze to make recommendations to the
# company, and what data visualizations would you use to present your findings?

# %% [markdown]
# #Ans16.
# To analyze the most successfull app developers, we have to analyze-
# - Number of Downloads
# - Those apps which have good ratings
# - Which had postive Reviews
#
# Visualisations to present the findings-
# - Line Graphs
# - Countplot
# - Scatter plots to show the corelation among different features

# %% [markdown]
# Q17. A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to
# launch a new app. What features would you analyze to make recommendations to the company, and
# what data visualizations would you use to present your findings?

# %% [markdown]
# #Ans17
# Best time to Launch the App-
# - Trends according to the reviews, ratings and number of downloads
# - Weekends has higher number of downloads
# - Categorized the performance of App of different Genre
#
# Visualization Tools-
# * Line Graphs
# * Countplot
# * Scatter plots to show the corelation among different features
